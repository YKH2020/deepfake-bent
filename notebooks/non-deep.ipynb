# %%
import os
import shutil
import random

# %%
def create_splits(root_dir,
                  test_list_filename="List_of_testing_videos.txt",
                  subfolders=["Celeb-synthesis", "Youtube-real", "Celeb-real"],
                  train_ratio=0.8):
    """
    Reads the test list file (ignoring the first number on each line) and
    copies videos from the specified subfolders into a 'test' folder if their
    relative path (e.g., "Youtube-real/00170.mp4") is in the list.
    Then, the remaining videos are randomly split into 'train' and 'val'
    folders according to the train_ratio.
    
    Parameters:
      root_dir (str): The path to the "celeb-df" folder.
      test_list_filename (str): Name of the text file containing test video paths.
      subfolders (list of str): The subfolders (relative to root_dir) to search.
      train_ratio (float): Fraction of the remaining (non-test) videos to go to train.
    """
    # Create output directories
    test_dir = os.path.join(root_dir, "test")
    train_dir = os.path.join(root_dir, "train")
    val_dir   = os.path.join(root_dir, "val")
    os.makedirs(test_dir, exist_ok=True)
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # Read the test file and parse each line.
    # Each line is assumed to be: "<number> <relative_path>"
    test_list_path = os.path.join(root_dir, test_list_filename)
    test_paths = set()
    with open(test_list_path, 'r') as f:
        for line in f:
            # Split the line by whitespace
            parts = line.strip().split()
            if len(parts) >= 2:
                # Use the second token as the relative path
                rel_path = parts[1].strip()
                # For robust matching, store as lower-case
                test_paths.add(rel_path.lower())

    remaining_files = []  # List to store non-test video file paths

    # Loop through each specified subfolder
    for folder in subfolders:
        folder_path = os.path.join(root_dir, folder)
        if not os.path.isdir(folder_path):
            print(f"Folder '{folder_path}' not found. Skipping.")
            continue

        for file_name in os.listdir(folder_path):
            if file_name.lower().endswith(".mp4"):
                # Construct the relative path as it would appear in the test list.
                # For example: "Youtube-real/00170.mp4"
                relative_path = os.path.join(folder, file_name).replace("\\", "/")
                # Compare in lower-case for robustness.
                if relative_path.lower() in test_paths:
                    dest_file = os.path.join(test_dir, file_name)
                    print(f"Copying {os.path.join(folder_path, file_name)} to {dest_file} (test set)")
                    shutil.copy2(os.path.join(folder_path, file_name), dest_file)
                else:
                    remaining_files.append(os.path.join(folder_path, file_name))

    # Shuffle the remaining (non-test) videos
    random.shuffle(remaining_files)
    num_remaining = len(remaining_files)
    num_train = int(train_ratio * num_remaining)

    train_files = remaining_files[:num_train]
    val_files = remaining_files[num_train:]

    # Copy training files
    for source_file in train_files:
        file_name = os.path.basename(source_file)
        dest_file = os.path.join(train_dir, file_name)
        print(f"Copying {source_file} to {dest_file} (train set)")
        shutil.copy2(source_file, dest_file)

    # Copy validation files
    for source_file in val_files:
        file_name = os.path.basename(source_file)
        dest_file = os.path.join(val_dir, file_name)
        print(f"Copying {source_file} to {dest_file} (val set)")
        shutil.copy2(source_file, dest_file)

    print(f"Done. Total non-test videos: {num_remaining}. Train: {len(train_files)}, Val: {len(val_files)}.")

# Set your root directory (e.g., the folder "celeb-df")
root_directory = "Celeb-DF"
create_splits(root_directory)
# Out:
# Copying Celeb-DF\Celeb-synthesis\id10_id11_0001.mp4 to Celeb-DF\test\id10_id11_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id10_id11_0004.mp4 to Celeb-DF\test\id10_id11_0004.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id10_id12_0001.mp4 to Celeb-DF\test\id10_id12_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id10_id12_0004.mp4 to Celeb-DF\test\id10_id12_0004.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id10_id13_0001.mp4 to Celeb-DF\test\id10_id13_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id10_id13_0004.mp4 to Celeb-DF\test\id10_id13_0004.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id10_id7_0001.mp4 to Celeb-DF\test\id10_id7_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id10_id7_0004.mp4 to Celeb-DF\test\id10_id7_0004.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id11_id7_0008.mp4 to Celeb-DF\test\id11_id7_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id16_id0_0011.mp4 to Celeb-DF\test\id16_id0_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0011.mp4 to Celeb-DF\test\id16_id17_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id16_id1_0011.mp4 to Celeb-DF\test\id16_id1_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0011.mp4 to Celeb-DF\test\id16_id2_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id16_id3_0011.mp4 to Celeb-DF\test\id16_id3_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0011.mp4 to Celeb-DF\test\id16_id6_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0011.mp4 to Celeb-DF\test\id16_id9_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id17_id0_0000.mp4 to Celeb-DF\test\id17_id0_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id17_id16_0000.mp4 to Celeb-DF\test\id17_id16_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0000.mp4 to Celeb-DF\test\id17_id1_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id17_id2_0000.mp4 to Celeb-DF\test\id17_id2_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0000.mp4 to Celeb-DF\test\id17_id3_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id17_id6_0000.mp4 to Celeb-DF\test\id17_id6_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id17_id9_0000.mp4 to Celeb-DF\test\id17_id9_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id0_0007.mp4 to Celeb-DF\test\id1_id0_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id16_0007.mp4 to Celeb-DF\test\id1_id16_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0007.mp4 to Celeb-DF\test\id1_id17_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id2_0007.mp4 to Celeb-DF\test\id1_id2_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id3_0007.mp4 to Celeb-DF\test\id1_id3_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id4_0007.mp4 to Celeb-DF\test\id1_id4_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id6_0007.mp4 to Celeb-DF\test\id1_id6_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id1_id9_0007.mp4 to Celeb-DF\test\id1_id9_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id2_id0_0008.mp4 to Celeb-DF\test\id2_id0_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id2_id16_0008.mp4 to Celeb-DF\test\id2_id16_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id2_id17_0008.mp4 to Celeb-DF\test\id2_id17_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id2_id1_0008.mp4 to Celeb-DF\test\id2_id1_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id2_id3_0008.mp4 to Celeb-DF\test\id2_id3_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id2_id9_0008.mp4 to Celeb-DF\test\id2_id9_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id3_id16_0001.mp4 to Celeb-DF\test\id3_id16_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id3_id17_0001.mp4 to Celeb-DF\test\id3_id17_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id3_id1_0001.mp4 to Celeb-DF\test\id3_id1_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id3_id2_0001.mp4 to Celeb-DF\test\id3_id2_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id3_id4_0001.mp4 to Celeb-DF\test\id3_id4_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id3_id6_0001.mp4 to Celeb-DF\test\id3_id6_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id3_id9_0001.mp4 to Celeb-DF\test\id3_id9_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0003.mp4 to Celeb-DF\test\id4_id1_0003.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id6_id0_0005.mp4 to Celeb-DF\test\id6_id0_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id6_id16_0005.mp4 to Celeb-DF\test\id6_id16_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id6_id17_0005.mp4 to Celeb-DF\test\id6_id17_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0005.mp4 to Celeb-DF\test\id6_id1_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id6_id2_0005.mp4 to Celeb-DF\test\id6_id2_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id6_id3_0005.mp4 to Celeb-DF\test\id6_id3_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id6_id9_0005.mp4 to Celeb-DF\test\id6_id9_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id7_id10_0009.mp4 to Celeb-DF\test\id7_id10_0009.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id7_id11_0009.mp4 to Celeb-DF\test\id7_id11_0009.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id7_id13_0009.mp4 to Celeb-DF\test\id7_id13_0009.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id9_id0_0000.mp4 to Celeb-DF\test\id9_id0_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id9_id16_0000.mp4 to Celeb-DF\test\id9_id16_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id9_id17_0000.mp4 to Celeb-DF\test\id9_id17_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id9_id1_0000.mp4 to Celeb-DF\test\id9_id1_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id9_id2_0000.mp4 to Celeb-DF\test\id9_id2_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id9_id3_0000.mp4 to Celeb-DF\test\id9_id3_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-synthesis\id9_id6_0000.mp4 to Celeb-DF\test\id9_id6_0000.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00011.mp4 to Celeb-DF\test\00011.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00021.mp4 to Celeb-DF\test\00021.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00023.mp4 to Celeb-DF\test\00023.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00024.mp4 to Celeb-DF\test\00024.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00036.mp4 to Celeb-DF\test\00036.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00047.mp4 to Celeb-DF\test\00047.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00048.mp4 to Celeb-DF\test\00048.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00061.mp4 to Celeb-DF\test\00061.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00063.mp4 to Celeb-DF\test\00063.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00076.mp4 to Celeb-DF\test\00076.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00082.mp4 to Celeb-DF\test\00082.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00092.mp4 to Celeb-DF\test\00092.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00095.mp4 to Celeb-DF\test\00095.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00106.mp4 to Celeb-DF\test\00106.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00119.mp4 to Celeb-DF\test\00119.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00133.mp4 to Celeb-DF\test\00133.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00138.mp4 to Celeb-DF\test\00138.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00168.mp4 to Celeb-DF\test\00168.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00170.mp4 to Celeb-DF\test\00170.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00188.mp4 to Celeb-DF\test\00188.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00193.mp4 to Celeb-DF\test\00193.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00194.mp4 to Celeb-DF\test\00194.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00197.mp4 to Celeb-DF\test\00197.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00202.mp4 to Celeb-DF\test\00202.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00207.mp4 to Celeb-DF\test\00207.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00208.mp4 to Celeb-DF\test\00208.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00213.mp4 to Celeb-DF\test\00213.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00227.mp4 to Celeb-DF\test\00227.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00236.mp4 to Celeb-DF\test\00236.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00244.mp4 to Celeb-DF\test\00244.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id11_0008.mp4 to Celeb-DF\test\id11_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id16_0011.mp4 to Celeb-DF\test\id16_0011.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id17_0000.mp4 to Celeb-DF\test\id17_0000.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id1_0007.mp4 to Celeb-DF\test\id1_0007.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id2_0008.mp4 to Celeb-DF\test\id2_0008.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id3_0001.mp4 to Celeb-DF\test\id3_0001.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id6_0005.mp4 to Celeb-DF\test\id6_0005.mp4 (test set)
# Copying Celeb-DF\Celeb-real\id9_0000.mp4 to Celeb-DF\test\id9_0000.mp4 (test set)
# Copying Celeb-DF\Youtube-real\00029.mp4 to Celeb-DF\train\00029.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00105.mp4 to Celeb-DF\train\00105.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id3_0005.mp4 to Celeb-DF\train\id3_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id4_0004.mp4 to Celeb-DF\train\id9_id4_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id1_0006.mp4 to Celeb-DF\train\id1_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id0_0005.mp4 to Celeb-DF\train\id3_id0_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00056.mp4 to Celeb-DF\train\00056.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id1_0003.mp4 to Celeb-DF\train\id1_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id12_0001.mp4 to Celeb-DF\train\id12_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id2_0001.mp4 to Celeb-DF\train\id1_id2_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id6_0005.mp4 to Celeb-DF\train\id4_id6_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00118.mp4 to Celeb-DF\train\00118.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id0_0003.mp4 to Celeb-DF\train\id9_id0_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id12_0007.mp4 to Celeb-DF\train\id10_id12_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0009.mp4 to Celeb-DF\train\id4_id0_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id4_0009.mp4 to Celeb-DF\train\id0_id4_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id12_id10_0001.mp4 to Celeb-DF\train\id12_id10_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id2_0004.mp4 to Celeb-DF\train\id17_id2_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id0_0009.mp4 to Celeb-DF\train\id2_id0_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0001.mp4 to Celeb-DF\train\id4_id0_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0004.mp4 to Celeb-DF\train\id16_id9_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id6_0006.mp4 to Celeb-DF\train\id6_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id9_0001.mp4 to Celeb-DF\train\id2_id9_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id3_0009.mp4 to Celeb-DF\train\id9_id3_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id1_0002.mp4 to Celeb-DF\train\id16_id1_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id0_0004.mp4 to Celeb-DF\train\id0_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id3_0009.mp4 to Celeb-DF\train\id4_id3_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00059.mp4 to Celeb-DF\train\00059.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id4_0001.mp4 to Celeb-DF\train\id1_id4_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id16_0004.mp4 to Celeb-DF\train\id9_id16_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id12_id7_0004.mp4 to Celeb-DF\train\id12_id7_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id16_0003.mp4 to Celeb-DF\train\id6_id16_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id0_0006.mp4 to Celeb-DF\train\id2_id0_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id7_0008.mp4 to Celeb-DF\train\id10_id7_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id13_0002.mp4 to Celeb-DF\train\id10_id13_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00045.mp4 to Celeb-DF\train\00045.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00043.mp4 to Celeb-DF\train\00043.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id10_0007.mp4 to Celeb-DF\train\id7_id10_0007.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00211.mp4 to Celeb-DF\train\00211.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id9_0005.mp4 to Celeb-DF\train\id2_id9_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id3_0007.mp4 to Celeb-DF\train\id9_id3_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0003.mp4 to Celeb-DF\train\id13_id7_0003.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00090.mp4 to Celeb-DF\train\00090.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id9_0002.mp4 to Celeb-DF\train\id9_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id8_0007.mp4 to Celeb-DF\train\id8_0007.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00160.mp4 to Celeb-DF\train\00160.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id9_0005.mp4 to Celeb-DF\train\id0_id9_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00116.mp4 to Celeb-DF\train\00116.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id7_0007.mp4 to Celeb-DF\train\id7_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id2_0000.mp4 to Celeb-DF\train\id6_id2_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0004.mp4 to Celeb-DF\train\id17_id1_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0001.mp4 to Celeb-DF\train\id17_id3_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id12_0006.mp4 to Celeb-DF\train\id12_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0009.mp4 to Celeb-DF\train\id16_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0004.mp4 to Celeb-DF\train\id13_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id6_0002.mp4 to Celeb-DF\train\id3_id6_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id3_0006.mp4 to Celeb-DF\train\id9_id3_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id4_0006.mp4 to Celeb-DF\train\id3_id4_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id9_0008.mp4 to Celeb-DF\train\id0_id9_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id2_0007.mp4 to Celeb-DF\train\id6_id2_0007.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00243.mp4 to Celeb-DF\train\00243.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id6_0008.mp4 to Celeb-DF\train\id8_id6_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0003.mp4 to Celeb-DF\train\id17_id3_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id3_0000.mp4 to Celeb-DF\train\id2_id3_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0006.mp4 to Celeb-DF\train\id17_id1_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0001.mp4 to Celeb-DF\train\id16_id2_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id3_0004.mp4 to Celeb-DF\train\id4_id3_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id11_0005.mp4 to Celeb-DF\train\id10_id11_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id6_0004.mp4 to Celeb-DF\train\id3_id6_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id17_0009.mp4 to Celeb-DF\train\id6_id17_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id13_0000.mp4 to Celeb-DF\train\id7_id13_0000.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00154.mp4 to Celeb-DF\train\00154.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id2_0009.mp4 to Celeb-DF\train\id17_id2_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id9_0005.mp4 to Celeb-DF\train\id1_id9_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id4_0001.mp4 to Celeb-DF\train\id6_id4_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id16_0004.mp4 to Celeb-DF\train\id17_id16_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id2_0001.mp4 to Celeb-DF\train\id6_id2_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0010.mp4 to Celeb-DF\train\id13_0010.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id8_0002.mp4 to Celeb-DF\train\id8_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0015.mp4 to Celeb-DF\train\id13_0015.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id7_0007.mp4 to Celeb-DF\train\id10_id7_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id12_id7_0001.mp4 to Celeb-DF\train\id12_id7_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id3_0007.mp4 to Celeb-DF\train\id3_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0000.mp4 to Celeb-DF\train\id16_id6_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id9_0003.mp4 to Celeb-DF\train\id17_id9_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id0_0000.mp4 to Celeb-DF\train\id3_id0_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id16_0009.mp4 to Celeb-DF\train\id1_id16_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id13_0007.mp4 to Celeb-DF\train\id10_id13_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id17_0004.mp4 to Celeb-DF\train\id9_id17_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id12_0000.mp4 to Celeb-DF\train\id7_id12_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id6_0009.mp4 to Celeb-DF\train\id4_id6_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id6_0005.mp4 to Celeb-DF\train\id9_id6_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00149.mp4 to Celeb-DF\train\00149.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id16_0003.mp4 to Celeb-DF\train\id2_id16_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id0_0005.mp4 to Celeb-DF\train\id9_id0_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id3_0007.mp4 to Celeb-DF\train\id0_id3_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id2_0006.mp4 to Celeb-DF\train\id6_id2_0006.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00017.mp4 to Celeb-DF\train\00017.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id1_0009.mp4 to Celeb-DF\train\id1_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00174.mp4 to Celeb-DF\train\00174.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id2_0005.mp4 to Celeb-DF\train\id0_id2_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id3_0004.mp4 to Celeb-DF\train\id1_id3_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00067.mp4 to Celeb-DF\train\00067.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0003.mp4 to Celeb-DF\train\id16_id9_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id2_0009.mp4 to Celeb-DF\train\id9_id2_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id6_0000.mp4 to Celeb-DF\train\id4_id6_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id3_0009.mp4 to Celeb-DF\train\id1_id3_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id12_0003.mp4 to Celeb-DF\train\id12_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id10_0000.mp4 to Celeb-DF\train\id10_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0008.mp4 to Celeb-DF\train\id4_id1_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0000.mp4 to Celeb-DF\train\id13_id7_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id1_0003.mp4 to Celeb-DF\train\id0_id1_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0009.mp4 to Celeb-DF\train\id16_id17_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id10_0007.mp4 to Celeb-DF\train\id13_id10_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id1_0007.mp4 to Celeb-DF\train\id0_id1_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id1_0008.mp4 to Celeb-DF\train\id3_id1_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id12_0008.mp4 to Celeb-DF\train\id10_id12_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id6_0005.mp4 to Celeb-DF\train\id3_id6_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0001.mp4 to Celeb-DF\train\id6_id1_0001.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00038.mp4 to Celeb-DF\train\00038.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00068.mp4 to Celeb-DF\train\00068.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id9_0007.mp4 to Celeb-DF\train\id3_id9_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id16_0005.mp4 to Celeb-DF\train\id0_id16_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0006.mp4 to Celeb-DF\train\id4_id1_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id9_0000.mp4 to Celeb-DF\train\id2_id9_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id11_0004.mp4 to Celeb-DF\train\id7_id11_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id10_0008.mp4 to Celeb-DF\train\id13_id10_0008.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00230.mp4 to Celeb-DF\train\00230.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id16_0009.mp4 to Celeb-DF\train\id17_id16_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00070.mp4 to Celeb-DF\train\00070.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id16_0009.mp4 to Celeb-DF\train\id3_id16_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0006.mp4 to Celeb-DF\train\id16_id6_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id6_0007.mp4 to Celeb-DF\train\id4_id6_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id17_0008.mp4 to Celeb-DF\train\id17_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id6_0008.mp4 to Celeb-DF\train\id9_id6_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id3_0007.mp4 to Celeb-DF\train\id4_id3_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id16_0003.mp4 to Celeb-DF\train\id17_id16_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id11_0009.mp4 to Celeb-DF\train\id11_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00020.mp4 to Celeb-DF\train\00020.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id7_0006.mp4 to Celeb-DF\train\id10_id7_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id17_0007.mp4 to Celeb-DF\train\id2_id17_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id4_0002.mp4 to Celeb-DF\train\id4_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id2_0004.mp4 to Celeb-DF\train\id1_id2_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00110.mp4 to Celeb-DF\train\00110.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0007.mp4 to Celeb-DF\train\id16_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id6_0007.mp4 to Celeb-DF\train\id2_id6_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id2_0005.mp4 to Celeb-DF\train\id17_id2_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00084.mp4 to Celeb-DF\train\00084.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id3_0000.mp4 to Celeb-DF\train\id1_id3_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id2_0004.mp4 to Celeb-DF\train\id0_id2_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id12_0007.mp4 to Celeb-DF\train\id7_id12_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id3_0004.mp4 to Celeb-DF\train\id0_id3_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00186.mp4 to Celeb-DF\train\00186.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id2_0004.mp4 to Celeb-DF\train\id3_id2_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0003.mp4 to Celeb-DF\train\id16_id17_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id3_0009.mp4 to Celeb-DF\train\id0_id3_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id2_0003.mp4 to Celeb-DF\train\id3_id2_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id6_0002.mp4 to Celeb-DF\train\id2_id6_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0006.mp4 to Celeb-DF\train\id6_id1_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id1_0007.mp4 to Celeb-DF\train\id8_id1_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0001.mp4 to Celeb-DF\train\id16_id9_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0003.mp4 to Celeb-DF\train\id17_id1_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0002.mp4 to Celeb-DF\train\id4_id1_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id16_0003.mp4 to Celeb-DF\train\id0_id16_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id10_0004.mp4 to Celeb-DF\train\id7_id10_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0004.mp4 to Celeb-DF\train\id1_id17_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id9_0002.mp4 to Celeb-DF\train\id0_id9_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0006.mp4 to Celeb-DF\train\id16_id9_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id17_0006.mp4 to Celeb-DF\train\id2_id17_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id6_0003.mp4 to Celeb-DF\train\id3_id6_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id0_0013.mp4 to Celeb-DF\train\id16_id0_0013.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id16_0004.mp4 to Celeb-DF\train\id6_id16_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id4_0007.mp4 to Celeb-DF\train\id2_id4_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id4_0005.mp4 to Celeb-DF\train\id3_id4_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00229.mp4 to Celeb-DF\train\00229.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0002.mp4 to Celeb-DF\train\id4_id0_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00224.mp4 to Celeb-DF\train\00224.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0014.mp4 to Celeb-DF\train\id13_0014.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00192.mp4 to Celeb-DF\train\00192.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id16_0001.mp4 to Celeb-DF\train\id1_id16_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id8_0008.mp4 to Celeb-DF\train\id8_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id6_0002.mp4 to Celeb-DF\train\id6_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00012.mp4 to Celeb-DF\train\00012.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0000.mp4 to Celeb-DF\train\id16_id9_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id4_0008.mp4 to Celeb-DF\train\id9_id4_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id17_0009.mp4 to Celeb-DF\train\id2_id17_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id4_0006.mp4 to Celeb-DF\train\id2_id4_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id0_0002.mp4 to Celeb-DF\train\id6_id0_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0001.mp4 to Celeb-DF\train\id13_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id11_0005.mp4 to Celeb-DF\train\id11_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00172.mp4 to Celeb-DF\train\00172.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id3_0002.mp4 to Celeb-DF\train\id9_id3_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0012.mp4 to Celeb-DF\train\id13_id7_0012.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id0_0000.mp4 to Celeb-DF\train\id0_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0009.mp4 to Celeb-DF\train\id1_id17_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00139.mp4 to Celeb-DF\train\00139.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0004.mp4 to Celeb-DF\train\id16_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00246.mp4 to Celeb-DF\train\00246.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id12_id7_0002.mp4 to Celeb-DF\train\id12_id7_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id2_0001.mp4 to Celeb-DF\train\id2_0001.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00013.mp4 to Celeb-DF\train\00013.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id11_0010.mp4 to Celeb-DF\train\id11_0010.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id17_0005.mp4 to Celeb-DF\train\id17_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00001.mp4 to Celeb-DF\train\00001.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00046.mp4 to Celeb-DF\train\00046.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id6_0007.mp4 to Celeb-DF\train\id17_id6_0007.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00166.mp4 to Celeb-DF\train\00166.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0008.mp4 to Celeb-DF\train\id13_id7_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id0_0006.mp4 to Celeb-DF\train\id9_id0_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0001.mp4 to Celeb-DF\train\id17_id1_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id0_0006.mp4 to Celeb-DF\train\id17_id0_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0010.mp4 to Celeb-DF\train\id16_id17_0010.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id6_0007.mp4 to Celeb-DF\train\id0_id6_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id12_0004.mp4 to Celeb-DF\train\id7_id12_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00215.mp4 to Celeb-DF\train\00215.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00072.mp4 to Celeb-DF\train\00072.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id3_0013.mp4 to Celeb-DF\train\id16_id3_0013.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00057.mp4 to Celeb-DF\train\00057.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id17_0003.mp4 to Celeb-DF\train\id6_id17_0003.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00189.mp4 to Celeb-DF\train\00189.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00140.mp4 to Celeb-DF\train\00140.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00121.mp4 to Celeb-DF\train\00121.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0007.mp4 to Celeb-DF\train\id4_id1_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id10_0006.mp4 to Celeb-DF\train\id10_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id2_0007.mp4 to Celeb-DF\train\id17_id2_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id0_0004.mp4 to Celeb-DF\train\id3_id0_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id0_0003.mp4 to Celeb-DF\train\id6_id0_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id9_0008.mp4 to Celeb-DF\train\id8_id9_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0000.mp4 to Celeb-DF\train\id13_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id7_0009.mp4 to Celeb-DF\train\id7_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0000.mp4 to Celeb-DF\train\id1_id17_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id6_0006.mp4 to Celeb-DF\train\id4_id6_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0009.mp4 to Celeb-DF\train\id17_id1_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00127.mp4 to Celeb-DF\train\00127.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00034.mp4 to Celeb-DF\train\00034.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id2_0007.mp4 to Celeb-DF\train\id9_id2_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id16_0007.mp4 to Celeb-DF\train\id17_id16_0007.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00226.mp4 to Celeb-DF\train\00226.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00248.mp4 to Celeb-DF\train\00248.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id10_0001.mp4 to Celeb-DF\train\id7_id10_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0012.mp4 to Celeb-DF\train\id16_id6_0012.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0013.mp4 to Celeb-DF\train\id13_0013.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id6_0004.mp4 to Celeb-DF\train\id17_id6_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id9_0003.mp4 to Celeb-DF\train\id2_id9_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0006.mp4 to Celeb-DF\train\id17_id3_0006.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00156.mp4 to Celeb-DF\train\00156.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0002.mp4 to Celeb-DF\train\id16_id9_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id6_0003.mp4 to Celeb-DF\train\id8_id6_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id0_0002.mp4 to Celeb-DF\train\id3_id0_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00074.mp4 to Celeb-DF\train\00074.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id7_0005.mp4 to Celeb-DF\train\id10_id7_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id0_0010.mp4 to Celeb-DF\train\id16_id0_0010.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id0_0003.mp4 to Celeb-DF\train\id17_id0_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0005.mp4 to Celeb-DF\train\id4_id0_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id4_0003.mp4 to Celeb-DF\train\id3_id4_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id6_0001.mp4 to Celeb-DF\train\id9_id6_0001.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00100.mp4 to Celeb-DF\train\00100.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id1_0006.mp4 to Celeb-DF\train\id2_id1_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id16_0004.mp4 to Celeb-DF\train\id0_id16_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00222.mp4 to Celeb-DF\train\00222.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id6_0007.mp4 to Celeb-DF\train\id6_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id4_0009.mp4 to Celeb-DF\train\id6_id4_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id6_0007.mp4 to Celeb-DF\train\id8_id6_0007.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00205.mp4 to Celeb-DF\train\00205.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0007.mp4 to Celeb-DF\train\id17_id3_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0006.mp4 to Celeb-DF\train\id4_id0_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id3_0010.mp4 to Celeb-DF\train\id16_id3_0010.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0013.mp4 to Celeb-DF\train\id16_0013.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id4_0008.mp4 to Celeb-DF\train\id3_id4_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id3_0002.mp4 to Celeb-DF\train\id2_id3_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0010.mp4 to Celeb-DF\train\id16_id2_0010.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id17_0007.mp4 to Celeb-DF\train\id0_id17_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id3_0001.mp4 to Celeb-DF\train\id2_id3_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id0_0004.mp4 to Celeb-DF\train\id2_id0_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id1_0006.mp4 to Celeb-DF\train\id3_id1_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id7_0006.mp4 to Celeb-DF\train\id7_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0012.mp4 to Celeb-DF\train\id16_id17_0012.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id3_0003.mp4 to Celeb-DF\train\id16_id3_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id17_0006.mp4 to Celeb-DF\train\id3_id17_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0005.mp4 to Celeb-DF\train\id4_id1_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00221.mp4 to Celeb-DF\train\00221.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0003.mp4 to Celeb-DF\train\id1_id17_0003.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00209.mp4 to Celeb-DF\train\00209.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id0_0003.mp4 to Celeb-DF\train\id2_id0_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id11_0006.mp4 to Celeb-DF\train\id10_id11_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id10_0004.mp4 to Celeb-DF\train\id10_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0006.mp4 to Celeb-DF\train\id16_id2_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id16_0004.mp4 to Celeb-DF\train\id3_id16_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id13_0008.mp4 to Celeb-DF\train\id10_id13_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id17_0006.mp4 to Celeb-DF\train\id6_id17_0006.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00101.mp4 to Celeb-DF\train\00101.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id0_0004.mp4 to Celeb-DF\train\id1_id0_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id12_id10_0002.mp4 to Celeb-DF\train\id12_id10_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00032.mp4 to Celeb-DF\train\00032.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id6_0002.mp4 to Celeb-DF\train\id8_id6_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00158.mp4 to Celeb-DF\train\00158.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id16_0007.mp4 to Celeb-DF\train\id0_id16_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id1_0002.mp4 to Celeb-DF\train\id1_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00220.mp4 to Celeb-DF\train\00220.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id9_0007.mp4 to Celeb-DF\train\id8_id9_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id16_0006.mp4 to Celeb-DF\train\id3_id16_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id11_id7_0007.mp4 to Celeb-DF\train\id11_id7_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0013.mp4 to Celeb-DF\train\id16_id2_0013.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id8_0000.mp4 to Celeb-DF\train\id8_0000.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00238.mp4 to Celeb-DF\train\00238.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id7_0000.mp4 to Celeb-DF\train\id7_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id0_0001.mp4 to Celeb-DF\train\id1_id0_0001.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00006.mp4 to Celeb-DF\train\00006.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00065.mp4 to Celeb-DF\train\00065.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0009.mp4 to Celeb-DF\train\id6_id1_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id16_0002.mp4 to Celeb-DF\train\id9_id16_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id17_0004.mp4 to Celeb-DF\train\id6_id17_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00225.mp4 to Celeb-DF\train\00225.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id17_0002.mp4 to Celeb-DF\train\id17_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id11_0006.mp4 to Celeb-DF\train\id7_id11_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id9_0004.mp4 to Celeb-DF\train\id9_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id17_0005.mp4 to Celeb-DF\train\id0_id17_0005.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00113.mp4 to Celeb-DF\train\00113.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id2_0006.mp4 to Celeb-DF\train\id0_id2_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id6_0001.mp4 to Celeb-DF\train\id17_id6_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id1_0000.mp4 to Celeb-DF\train\id2_id1_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id2_0002.mp4 to Celeb-DF\train\id1_id2_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00218.mp4 to Celeb-DF\train\00218.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id9_0009.mp4 to Celeb-DF\train\id17_id9_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id8_0004.mp4 to Celeb-DF\train\id8_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id8_id5_0003.mp4 to Celeb-DF\train\id8_id5_0003.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00183.mp4 to Celeb-DF\train\00183.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0008.mp4 to Celeb-DF\train\id6_id1_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id10_0001.mp4 to Celeb-DF\train\id13_id10_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0003.mp4 to Celeb-DF\train\id16_id6_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0013.mp4 to Celeb-DF\train\id16_id6_0013.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id2_0008.mp4 to Celeb-DF\train\id9_id2_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0005.mp4 to Celeb-DF\train\id17_id3_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0007.mp4 to Celeb-DF\train\id16_id17_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id17_0004.mp4 to Celeb-DF\train\id2_id17_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id1_0001.mp4 to Celeb-DF\train\id2_id1_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0003.mp4 to Celeb-DF\train\id16_id2_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id9_0007.mp4 to Celeb-DF\train\id2_id9_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id17_0005.mp4 to Celeb-DF\train\id3_id17_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id1_0002.mp4 to Celeb-DF\train\id0_id1_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id10_0009.mp4 to Celeb-DF\train\id10_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0005.mp4 to Celeb-DF\train\id1_id17_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id9_0005.mp4 to Celeb-DF\train\id9_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id0_0001.mp4 to Celeb-DF\train\id0_0001.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00141.mp4 to Celeb-DF\train\00141.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id2_0002.mp4 to Celeb-DF\train\id3_id2_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00167.mp4 to Celeb-DF\train\00167.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id4_0007.mp4 to Celeb-DF\train\id6_id4_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id12_0003.mp4 to Celeb-DF\train\id10_id12_0003.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00181.mp4 to Celeb-DF\train\00181.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id16_0005.mp4 to Celeb-DF\train\id2_id16_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id12_id7_0006.mp4 to Celeb-DF\train\id12_id7_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0007.mp4 to Celeb-DF\train\id16_id6_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id4_0001.mp4 to Celeb-DF\train\id0_id4_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id2_0004.mp4 to Celeb-DF\train\id9_id2_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0008.mp4 to Celeb-DF\train\id13_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id4_0000.mp4 to Celeb-DF\train\id2_id4_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id0_0007.mp4 to Celeb-DF\train\id0_0007.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00175.mp4 to Celeb-DF\train\00175.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id4_0004.mp4 to Celeb-DF\train\id1_id4_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0003.mp4 to Celeb-DF\train\id6_id1_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id0_id3_0003.mp4 to Celeb-DF\train\id0_id3_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id0_0005.mp4 to Celeb-DF\train\id17_id0_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id7_0004.mp4 to Celeb-DF\train\id7_0004.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00155.mp4 to Celeb-DF\train\00155.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id10_id11_0002.mp4 to Celeb-DF\train\id10_id11_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id16_0006.mp4 to Celeb-DF\train\id17_id16_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0007.mp4 to Celeb-DF\train\id17_id1_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id10_0015.mp4 to Celeb-DF\train\id13_id10_0015.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0002.mp4 to Celeb-DF\train\id6_id1_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0009.mp4 to Celeb-DF\train\id17_id3_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id6_0000.mp4 to Celeb-DF\train\id1_id6_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id2_0000.mp4 to Celeb-DF\train\id2_0000.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00145.mp4 to Celeb-DF\train\00145.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id16_0006.mp4 to Celeb-DF\train\id1_id16_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id1_0007.mp4 to Celeb-DF\train\id2_id1_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0000.mp4 to Celeb-DF\train\id4_id1_0000.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id3_0003.mp4 to Celeb-DF\train\id2_id3_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0002.mp4 to Celeb-DF\train\id13_id7_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0006.mp4 to Celeb-DF\train\id16_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id9_0005.mp4 to Celeb-DF\train\id17_id9_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0001.mp4 to Celeb-DF\train\id4_id1_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id12_0004.mp4 to Celeb-DF\train\id12_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id0_0004.mp4 to Celeb-DF\train\id6_id0_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0002.mp4 to Celeb-DF\train\id17_id1_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id6_0009.mp4 to Celeb-DF\train\id9_id6_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id3_0004.mp4 to Celeb-DF\train\id6_id3_0004.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0010.mp4 to Celeb-DF\train\id16_0010.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0009.mp4 to Celeb-DF\train\id16_id9_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00005.mp4 to Celeb-DF\train\00005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id3_0006.mp4 to Celeb-DF\train\id6_id3_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id11_id7_0006.mp4 to Celeb-DF\train\id11_id7_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id13_id10_0014.mp4 to Celeb-DF\train\id13_id10_0014.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00146.mp4 to Celeb-DF\train\00146.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00111.mp4 to Celeb-DF\train\00111.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id3_id0_0008.mp4 to Celeb-DF\train\id3_id0_0008.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0009.mp4 to Celeb-DF\train\id16_id2_0009.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00195.mp4 to Celeb-DF\train\00195.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00002.mp4 to Celeb-DF\train\00002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id9_id4_0005.mp4 to Celeb-DF\train\id9_id4_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id1_0005.mp4 to Celeb-DF\train\id17_id1_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0002.mp4 to Celeb-DF\train\id16_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id2_id16_0002.mp4 to Celeb-DF\train\id2_id16_0002.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00184.mp4 to Celeb-DF\train\00184.mp4 (train set)
# Copying Celeb-DF\Youtube-real\00137.mp4 to Celeb-DF\train\00137.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0002.mp4 to Celeb-DF\train\id16_id6_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0009.mp4 to Celeb-DF\train\id13_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id4_id3_0006.mp4 to Celeb-DF\train\id4_id3_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id6_0003.mp4 to Celeb-DF\train\id17_id6_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id7_id11_0007.mp4 to Celeb-DF\train\id7_id11_0007.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id1_0005.mp4 to Celeb-DF\train\id1_0005.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id13_0006.mp4 to Celeb-DF\train\id13_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id17_id6_0002.mp4 to Celeb-DF\train\id17_id6_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id16_0003.mp4 to Celeb-DF\train\id16_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id11_0001.mp4 to Celeb-DF\train\id11_0001.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id16_id0_0006.mp4 to Celeb-DF\train\id16_id0_0006.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id11_0002.mp4 to Celeb-DF\train\id11_0002.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id6_id16_0009.mp4 to Celeb-DF\train\id6_id16_0009.mp4 (train set)
# Copying Celeb-DF\Celeb-synthesis\id1_id0_0003.mp4 to Celeb-DF\train\id1_id0_0003.mp4 (train set)
# Copying Celeb-DF\Celeb-real\id2_0005.mp4 to Celeb-DF\train\id2_0005.mp4 (train set)
# ...
# Copying Celeb-DF\Celeb-synthesis\id0_id9_0003.mp4 to Celeb-DF\val\id0_id9_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id10_id11_0008.mp4 to Celeb-DF\val\id10_id11_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id0_0007.mp4 to Celeb-DF\val\id9_id0_0007.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id17_0008.mp4 to Celeb-DF\val\id3_id17_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id6_0009.mp4 to Celeb-DF\val\id0_id6_0009.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id4_0002.mp4 to Celeb-DF\val\id1_id4_0002.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00164.mp4 to Celeb-DF\val\00164.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00182.mp4 to Celeb-DF\val\00182.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00120.mp4 to Celeb-DF\val\00120.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id17_0000.mp4 to Celeb-DF\val\id2_id17_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id8_id1_0002.mp4 to Celeb-DF\val\id8_id1_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0002.mp4 to Celeb-DF\val\id1_id17_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id3_0008.mp4 to Celeb-DF\val\id3_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id0_0006.mp4 to Celeb-DF\val\id3_id0_0006.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00132.mp4 to Celeb-DF\val\00132.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00109.mp4 to Celeb-DF\val\00109.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00022.mp4 to Celeb-DF\val\00022.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0012.mp4 to Celeb-DF\val\id16_id2_0012.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id6_id17_0001.mp4 to Celeb-DF\val\id6_id17_0001.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00051.mp4 to Celeb-DF\val\00051.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id4_0000.mp4 to Celeb-DF\val\id0_id4_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id0_0005.mp4 to Celeb-DF\val\id16_id0_0005.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00198.mp4 to Celeb-DF\val\00198.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id0_0000.mp4 to Celeb-DF\val\id2_id0_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id1_0008.mp4 to Celeb-DF\val\id9_id1_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id2_0008.mp4 to Celeb-DF\val\id0_id2_0008.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00159.mp4 to Celeb-DF\val\00159.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00165.mp4 to Celeb-DF\val\00165.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id7_id11_0000.mp4 to Celeb-DF\val\id7_id11_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id2_0005.mp4 to Celeb-DF\val\id1_id2_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id3_0003.mp4 to Celeb-DF\val\id1_id3_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id16_0008.mp4 to Celeb-DF\val\id9_id16_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id4_0009.mp4 to Celeb-DF\val\id4_0009.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id12_id10_0005.mp4 to Celeb-DF\val\id12_id10_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id0_0003.mp4 to Celeb-DF\val\id0_0003.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00179.mp4 to Celeb-DF\val\00179.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id8_id0_0003.mp4 to Celeb-DF\val\id8_id0_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id17_0002.mp4 to Celeb-DF\val\id9_id17_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id6_0005.mp4 to Celeb-DF\val\id1_id6_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id17_id0_0002.mp4 to Celeb-DF\val\id17_id0_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id6_0000.mp4 to Celeb-DF\val\id3_id6_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id3_0008.mp4 to Celeb-DF\val\id4_id3_0008.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00025.mp4 to Celeb-DF\val\00025.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00102.mp4 to Celeb-DF\val\00102.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id6_id1_0004.mp4 to Celeb-DF\val\id6_id1_0004.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id6_id9_0007.mp4 to Celeb-DF\val\id6_id9_0007.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id7_0001.mp4 to Celeb-DF\val\id7_0001.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00027.mp4 to Celeb-DF\val\00027.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00214.mp4 to Celeb-DF\val\00214.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id1_0004.mp4 to Celeb-DF\val\id1_0004.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id8_id1_0008.mp4 to Celeb-DF\val\id8_id1_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id16_0008.mp4 to Celeb-DF\val\id16_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id16_0006.mp4 to Celeb-DF\val\id2_id16_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id4_0003.mp4 to Celeb-DF\val\id1_id4_0003.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00087.mp4 to Celeb-DF\val\00087.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id6_0008.mp4 to Celeb-DF\val\id6_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id4_0006.mp4 to Celeb-DF\val\id4_0006.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00247.mp4 to Celeb-DF\val\00247.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00078.mp4 to Celeb-DF\val\00078.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id3_0002.mp4 to Celeb-DF\val\id4_id3_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id17_0000.mp4 to Celeb-DF\val\id0_id17_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id9_0007.mp4 to Celeb-DF\val\id0_id9_0007.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0007.mp4 to Celeb-DF\val\id13_id7_0007.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id13_0011.mp4 to Celeb-DF\val\id13_0011.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id6_id16_0002.mp4 to Celeb-DF\val\id6_id16_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id11_id7_0001.mp4 to Celeb-DF\val\id11_id7_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id17_id3_0002.mp4 to Celeb-DF\val\id17_id3_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0005.mp4 to Celeb-DF\val\id16_id6_0005.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00055.mp4 to Celeb-DF\val\00055.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id9_0001.mp4 to Celeb-DF\val\id4_id9_0001.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00152.mp4 to Celeb-DF\val\00152.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id4_0005.mp4 to Celeb-DF\val\id0_id4_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id7_0008.mp4 to Celeb-DF\val\id7_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id9_0005.mp4 to Celeb-DF\val\id3_id9_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id6_id0_0000.mp4 to Celeb-DF\val\id6_id0_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id4_0001.mp4 to Celeb-DF\val\id9_id4_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id13_0005.mp4 to Celeb-DF\val\id13_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id4_0006.mp4 to Celeb-DF\val\id0_id4_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id9_0001.mp4 to Celeb-DF\val\id1_id9_0001.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00117.mp4 to Celeb-DF\val\00117.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id9_0002.mp4 to Celeb-DF\val\id4_id9_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id1_0004.mp4 to Celeb-DF\val\id16_id1_0004.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id0_0005.mp4 to Celeb-DF\val\id0_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id2_0000.mp4 to Celeb-DF\val\id0_id2_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id1_0000.mp4 to Celeb-DF\val\id0_id1_0000.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00107.mp4 to Celeb-DF\val\00107.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id17_id2_0003.mp4 to Celeb-DF\val\id17_id2_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id7_id11_0005.mp4 to Celeb-DF\val\id7_id11_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id0_0001.mp4 to Celeb-DF\val\id16_id0_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id2_0006.mp4 to Celeb-DF\val\id9_id2_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id2_0002.mp4 to Celeb-DF\val\id0_id2_0002.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00200.mp4 to Celeb-DF\val\00200.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id16_0006.mp4 to Celeb-DF\val\id9_id16_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id0_0005.mp4 to Celeb-DF\val\id1_id0_0005.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00147.mp4 to Celeb-DF\val\00147.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id6_0001.mp4 to Celeb-DF\val\id2_id6_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id1_id17_0006.mp4 to Celeb-DF\val\id1_id17_0006.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00083.mp4 to Celeb-DF\val\00083.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id6_0006.mp4 to Celeb-DF\val\id0_id6_0006.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00126.mp4 to Celeb-DF\val\00126.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id2_0003.mp4 to Celeb-DF\val\id4_id2_0003.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00232.mp4 to Celeb-DF\val\00232.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00242.mp4 to Celeb-DF\val\00242.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id1_0003.mp4 to Celeb-DF\val\id2_id1_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0011.mp4 to Celeb-DF\val\id13_id7_0011.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0002.mp4 to Celeb-DF\val\id16_id17_0002.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00114.mp4 to Celeb-DF\val\00114.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00081.mp4 to Celeb-DF\val\00081.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id3_0009.mp4 to Celeb-DF\val\id16_id3_0009.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00064.mp4 to Celeb-DF\val\00064.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00031.mp4 to Celeb-DF\val\00031.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id16_0002.mp4 to Celeb-DF\val\id3_id16_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id12_0002.mp4 to Celeb-DF\val\id12_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id1_0001.mp4 to Celeb-DF\val\id9_id1_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id8_0006.mp4 to Celeb-DF\val\id8_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0010.mp4 to Celeb-DF\val\id16_id6_0010.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id6_0007.mp4 to Celeb-DF\val\id9_id6_0007.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id10_id13_0006.mp4 to Celeb-DF\val\id10_id13_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id2_0005.mp4 to Celeb-DF\val\id16_id2_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id3_0006.mp4 to Celeb-DF\val\id2_id3_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id17_0004.mp4 to Celeb-DF\val\id16_id17_0004.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id2_0006.mp4 to Celeb-DF\val\id4_id2_0006.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id13_id7_0004.mp4 to Celeb-DF\val\id13_id7_0004.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00062.mp4 to Celeb-DF\val\00062.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00040.mp4 to Celeb-DF\val\00040.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00128.mp4 to Celeb-DF\val\00128.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00131.mp4 to Celeb-DF\val\00131.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id4_0002.mp4 to Celeb-DF\val\id0_id4_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id16_0005.mp4 to Celeb-DF\val\id9_id16_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id10_id7_0009.mp4 to Celeb-DF\val\id10_id7_0009.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id3_0012.mp4 to Celeb-DF\val\id16_id3_0012.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00026.mp4 to Celeb-DF\val\00026.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00054.mp4 to Celeb-DF\val\00054.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id7_id13_0001.mp4 to Celeb-DF\val\id7_id13_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id3_0004.mp4 to Celeb-DF\val\id2_id3_0004.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id7_id12_0002.mp4 to Celeb-DF\val\id7_id12_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id2_0007.mp4 to Celeb-DF\val\id2_0007.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id16_0003.mp4 to Celeb-DF\val\id3_id16_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id6_0002.mp4 to Celeb-DF\val\id4_id6_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id2_0001.mp4 to Celeb-DF\val\id9_id2_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id11_id7_0005.mp4 to Celeb-DF\val\id11_id7_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id3_0009.mp4 to Celeb-DF\val\id3_0009.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00028.mp4 to Celeb-DF\val\00028.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00176.mp4 to Celeb-DF\val\00176.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id6_0004.mp4 to Celeb-DF\val\id9_id6_0004.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id7_id10_0002.mp4 to Celeb-DF\val\id7_id10_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id13_id10_0005.mp4 to Celeb-DF\val\id13_id10_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id1_0003.mp4 to Celeb-DF\val\id16_id1_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id1_0005.mp4 to Celeb-DF\val\id9_id1_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id1_0002.mp4 to Celeb-DF\val\id3_id1_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id8_id2_0002.mp4 to Celeb-DF\val\id8_id2_0002.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00033.mp4 to Celeb-DF\val\00033.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id16_0005.mp4 to Celeb-DF\val\id16_0005.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id9_0009.mp4 to Celeb-DF\val\id2_id9_0009.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00190.mp4 to Celeb-DF\val\00190.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id6_id9_0000.mp4 to Celeb-DF\val\id6_id9_0000.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id3_id16_0008.mp4 to Celeb-DF\val\id3_id16_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id1_0009.mp4 to Celeb-DF\val\id4_id1_0009.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id2_id4_0003.mp4 to Celeb-DF\val\id2_id4_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id17_id9_0002.mp4 to Celeb-DF\val\id17_id9_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id4_0007.mp4 to Celeb-DF\val\id9_id4_0007.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00097.mp4 to Celeb-DF\val\00097.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0003.mp4 to Celeb-DF\val\id4_id0_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0007.mp4 to Celeb-DF\val\id4_id0_0007.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00016.mp4 to Celeb-DF\val\00016.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id3_0002.mp4 to Celeb-DF\val\id3_0002.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id6_0001.mp4 to Celeb-DF\val\id16_id6_0001.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id4_id0_0008.mp4 to Celeb-DF\val\id4_id0_0008.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id9_id3_0004.mp4 to Celeb-DF\val\id9_id3_0004.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00148.mp4 to Celeb-DF\val\00148.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00180.mp4 to Celeb-DF\val\00180.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id8_id3_0003.mp4 to Celeb-DF\val\id8_id3_0003.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id1_0009.mp4 to Celeb-DF\val\id16_id1_0009.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id7_0005.mp4 to Celeb-DF\val\id7_0005.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00173.mp4 to Celeb-DF\val\00173.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00039.mp4 to Celeb-DF\val\00039.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id6_id2_0004.mp4 to Celeb-DF\val\id6_id2_0004.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00206.mp4 to Celeb-DF\val\00206.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id16_id9_0013.mp4 to Celeb-DF\val\id16_id9_0013.mp4 (val set)
# Copying Celeb-DF\Youtube-real\00069.mp4 to Celeb-DF\val\00069.mp4 (val set)
# Copying Celeb-DF\Celeb-real\id6_0004.mp4 to Celeb-DF\val\id6_0004.mp4 (val set)
# Copying Celeb-DF\Celeb-synthesis\id0_id16_0002.mp4 to Celeb-DF\val\id0_id16_0002.mp4 (val set)
# Done. Total non-test videos: 1103. Train: 882, Val: 221.

# %%
def extract_features(video_path):
    """
    Extract all features from a video in one pass.
    Returns a single feature vector combining all features.
    """
    # Initialize detectors and extractors
    sift = cv2.SIFT_create()
    face_detector = dlib.get_frontal_face_detector()
    landmark_predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
    mp_face_mesh = mp.solutions.face_mesh
    face_mesh = mp_face_mesh.FaceMesh()
    
    # Initialize feature lists
    all_features = []
    
    # Open video
    cap = cv2.VideoCapture(video_path)
    
    # Read first frame
    ret, prev_frame = cap.read()
    if not ret:
        return None
        
    # Convert to grayscale for initial frame
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    
    # 1. Basic Statistical Features
    all_features.extend([
        np.mean(prev_gray),
        np.std(prev_gray),
        np.max(prev_gray),
        np.min(prev_gray),
        skew(prev_gray.flatten()),
        kurtosis(prev_gray.flatten())
    ])
    
    # 2. Histogram Features
    hist = cv2.calcHist([prev_gray], [0], None, [256], [0, 256])
    hist = hist.flatten() / hist.sum()  # Normalize
    all_features.extend(hist)
    
    # 3. SIFT Features
    keypoints, descriptors = sift.detectAndCompute(prev_gray, None)
    if descriptors is not None:
        sift_features = [
            np.mean(descriptors),
            np.std(descriptors),
            skew(descriptors.flatten()),
            kurtosis(descriptors.flatten())
        ]
    else:
        sift_features = [0, 0, 0, 0]
    all_features.extend(sift_features)
    
    # 4. Edge and Texture Features
    blurred = cv2.GaussianBlur(prev_gray, (5,5), 0)
    all_features.extend([
        cv2.Laplacian(blurred, cv2.CV_64F).var(),
        cv2.Sobel(blurred, cv2.CV_64F, 1, 0, ksize=5).var(),
        cv2.Sobel(blurred, cv2.CV_64F, 0, 1, ksize=5).var()
    ])
    
    # Initialize motion and facial features accumulators
    motion_features = []
    facial_features = []
    quality_scores = []
    
    # Process first 30 frames (or less if video is shorter)
    frame_count = 0
    while cap.isOpened() and frame_count < 30:
        ret, curr_frame = cap.read()
        if not ret:
            break
            
        curr_gray = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY)
        
        # 5. Motion Features
        flow = cv2.calcOpticalFlowFarneback(
            prev_gray, curr_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0
        )
        mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
        motion_features.append([
            np.mean(mag),
            np.std(mag),
            np.mean(ang),
            np.std(ang)
        ])
        
        # 6. Facial Landmarks
        faces = face_detector(curr_gray)
        if len(faces) > 0:
            face = faces[0]
            landmarks = landmark_predictor(curr_gray, face)
            points = np.array([[p.x, p.y] for p in landmarks.parts()])
            
            # Calculate facial features
            distances = np.sqrt(np.sum(np.diff(points, axis=0)**2, axis=1))
            left_eye = points[36:42]
            right_eye = points[42:48]
            eye_asymmetry = np.mean(np.abs(left_eye - np.flip(right_eye, axis=0)))
            face_height = np.linalg.norm(points[8] - points[27])
            face_width = np.linalg.norm(points[0] - points[16])
            
            facial_features.append([
                np.mean(distances),
                np.std(distances),
                eye_asymmetry,
                face_height/face_width
            ])
        
        # 7. BRISQUE Quality Score
        try:
            quality_scores.append(brisque.score(curr_frame))
        except:
            quality_scores.append(0)
        
        prev_gray = curr_gray
        frame_count += 1
    
    cap.release()
    
    # Average temporal features
    if motion_features:
        all_features.extend(np.mean(motion_features, axis=0))
    else:
        all_features.extend([0, 0, 0, 0])
        
    if facial_features:
        all_features.extend(np.mean(facial_features, axis=0))
    else:
        all_features.extend([0, 0, 0, 0])
        
    if quality_scores:
        all_features.append(np.mean(quality_scores))
    else:
        all_features.append(0)
    
    return np.array(all_features)

# %%
import cv2
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import glob
from tqdm import tqdm
from skimage.feature import local_binary_pattern
from scipy.stats import kurtosis, skew
import dlib
import mediapipe as mp
from imquality import brisque
from xgboost import XGBClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
def extract_features(video_path):
    """Extract features from a video using traditional CV techniques."""
    # Open the video
    cap = cv2.VideoCapture(video_path)
    
    # Initialize features
    features = []
    
    # Read first frame
    success, frame = cap.read()
    if not success:
        return None
    
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Calculate basic statistical features
    features.extend([
        np.mean(gray),  # Mean intensity
        np.std(gray),   # Standard deviation of intensity
        np.max(gray),   # Maximum intensity
        np.min(gray),   # Minimum intensity
    ])
    
    # Calculate histogram features
    hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
    hist = hist.flatten()
    hist = hist / hist.sum()  # Normalize
    features.extend(hist)
    
    # Calculate Haralick texture features
    glcm = cv2.GaussianBlur(gray, (5,5), 0)
    features.extend([
        cv2.Laplacian(glcm, cv2.CV_64F).var(),  # Edge features
        cv2.Sobel(glcm, cv2.CV_64F, 1, 0, ksize=5).var(),  # Horizontal edges
        cv2.Sobel(glcm, cv2.CV_64F, 0, 1, ksize=5).var()   # Vertical edges
    ])
    
    cap.release()
    return np.array(features)

# %%
def process_dataset(base_path, file_limit=5):
    """Process all videos in the dataset and prepare for training, validation and testing."""
    X_train, y_train = [], []  # Training data
    X_val, y_val = [], []      # Validation data  
    X_test, y_test = [], []    # Test data
    
    # Process training data
    train_path = os.path.join(base_path, 'train', '*.mp4')
    for video_path in tqdm(glob.glob(train_path), desc="Processing training data"):
        filename = os.path.basename(video_path)
        label = 1 if filename.startswith('id') else 0
        features = extract_features(video_path)
        if features is not None:
            X_train.append(features)
            y_train.append(label)

    # Process validation data
    val_path = os.path.join(base_path, 'val', '*.mp4')
    for video_path in tqdm(glob.glob(val_path), desc="Processing validation data"):
        filename = os.path.basename(video_path)
        label = 1 if filename.startswith('id') else 0
        features = extract_features(video_path)
        if features is not None:
            X_val.append(features)
            y_val.append(label)
    
    # Process test data
    test_path = os.path.join(base_path, 'test', '*.mp4')
    for video_path in tqdm(glob.glob(test_path), desc="Processing test data"):
        filename = os.path.basename(video_path)
        label = 1 if filename.startswith('id') else 0
        features = extract_features(video_path)
        if features is not None:
            X_test.append(features)
            y_test.append(label)
    
    return (np.array(X_train), np.array(X_val), np.array(X_test),
            np.array(y_train), np.array(y_val), np.array(y_test))

# %%
def train_and_evaluate(X_train, X_val, X_test, y_train, y_val, y_test):
    """Train and evaluate model with validation set."""
    
    # Train model
    model = XGBClassifier(eval_metric='logloss', early_stopping_rounds=10)  
    # Train the model
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)
    
    # Predict on test set
    y_pred = model.predict(X_test)
    
    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print("\nTest Set Metrics:")
    print(f"Accuracy: {accuracy:.3f}")
    print(f"Precision: {precision:.3f}")
    print(f"Recall: {recall:.3f}") 
    print(f"F1 Score: {f1:.3f}")
    
    return model

# %%
def predict_video(model, video_path):
    """Predict whether a single video is real or fake."""
    features = extract_features(video_path)
    if features is not None:
        prediction = model.predict([features])[0]
        return "Fake" if prediction == 1 else "Real"
    return "Error processing video"

# %%
base_path = "Celeb-DF"  # Adjust this to your path

print("Processing dataset...")
X_train, X_test, X_val, y_train, y_val, y_test = process_dataset(base_path, file_limit=5)


# # Example of predicting a single video
# test_video = os.path.join(base_path, "test", "test_video.mp4")  # Adjust path as needed
# if os.path.exists(test_video):
#     result = predict_video(model, test_video)
#     print(f"\nTest video prediction: {result}")
# Out:
# Processing dataset...
# Processing training data: 100%|██████████| 1063/1063 [00:23<00:00, 46.07it/s]
# Processing validation data: 100%|██████████| 396/396 [00:12<00:00, 32.74it/s]
# Processing test data: 100%|██████████| 100/100 [00:02<00:00, 47.16it/s]

# %%
np.save('X.npy', X)
np.save('y.npy', y)

# %%
X_train.shape
# Out:
# (1063, 263)

# %%
model = train_and_evaluate(X_train,X_test,X_val,y_train,y_val,y_test)
# Out:
# Test Set Metrics:
# Accuracy: 0.770
# Precision: 0.885
# Recall: 0.771
# F1 Score: 0.824

# %%
#xgboost
model = train_and_evaluate(X, y)
# Out:
# Precision: 0.000
# Recall: 0.000
# F1 Score: 0.000
# c:\Users\thete\Github\deepfake-bent\newv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\thete\Github\deepfake-bent\newv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\thete\Github\deepfake-bent\newv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#forest
model = train_and_evaluate(X, y)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.49      0.64        35
#            1       0.89      0.99      0.94       142
#
#     accuracy                           0.89       177
#    macro avg       0.92      0.74      0.79       177
# weighted avg       0.90      0.89      0.88       177
